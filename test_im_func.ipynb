# %%
from image_functions import*

# %%
img = Image("EOS_R100/00000002.TIF")
img.show()

# %%
img.brightness_hist(0.5)
print(type(img.array))
# Out:
# <class 'numpy.ndarray'>

# %%
img.crop([5,3,500,300]).show()
