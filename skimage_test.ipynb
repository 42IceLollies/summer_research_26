# %%
import skimage
from skimage import io
import matplotlib.pyplot as plt

# %%
test_tiff = io.imread("EOS_R100/00000001.TIF")
test_jpg = io.imread("EOS_R100/IMG_0003.JPG")
fig, ax = plt.subplots(1,2, figsize = (20,12))
ax[0].imshow(test_tiff)
ax[1].imshow(test_jpg)
plt.show()

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(test_tiff[:1250, :1250])
ax[1].imshow(test_jpg[:750,:750])

plt.show()

# would be interesting to see if the computer can discern any differences between these
# differences in contrast?
# blur?

# %%
# Size?
jpg = io.imread("EOS_R100/IMG_0004.JPG")

print(len(test_tiff) * len(test_tiff[0]))
print(len(jpg)* len(jpg[0]))

# %%
with open("EOS_R100/IMG_0004.CR3", "rb" ) as file:
    data = file.read()
    print(data)
